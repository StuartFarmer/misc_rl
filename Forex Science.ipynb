# %%
import datetime

# %%
import csv
import pprint
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
data = []
with open('eurusd_daily_9am.csv', 'r') as f:  #opens PW file
    reader = csv.reader(f)
    # Print every value of every row. 
    for row in reader:
        new_row = []
        for value in row: 
            new_row.append(value)
        data.append(new_row)

# %%
#buy on friday, sell on monday
MONDAY = 0
FRIDAY = 4
important_dates = []
prior = None
for d in data:
    if prior != None:
        delta = parse(d[1]) - parse(prior[1])
        if delta.days == 3:
            important_dates.append(float(prior[3]) - float(d[3]))
    prior = d

# %%
pprint.pprint(important_dates)
# Out:
# [0.00029999999999996696,
#  0.008599999999999941,
#  0.014000000000000012,
#  0.0032999999999999696,
#  0.0007999999999999119,
#  -0.012299999999999978,
#  -0.006000000000000005,
#  -0.007900000000000018,
#  0.0045999999999999375,
#  0.0028000000000000247,
#  -0.0014999999999999458,
#  -0.0019000000000000128,
#  0.0040999999999999925,
#  -0.0031999999999999806,
#  -0.0044000000000000705,
#  0.012500000000000067,
#  0.0,
#  0.0035999999999999366,
#  0.0036999999999999256,
#  -0.0031999999999999806,
#  -0.005299999999999971,
#  0.0012999999999999678,
#  0.0008000000000000229,
#  -0.00880000000000003,
#  0.0020999999999999908,
#  -0.007800000000000029,
#  -0.0033000000000000806,
#  0.005600000000000049,
#  0.0017999999999999128,
#  0.0020000000000000018,
#  -0.0017000000000000348,
#  -0.0036000000000000476,
#  0.0017000000000000348,
#  0.008600000000000052,
#  -0.009299999999999975,
#  -0.01849999999999996,
#  0.010599999999999943,
#  0.005900000000000016,
#  -0.0042999999999999705,
# ...

# %%
ax = sns.distplot(important_dates)

# %%
ax = sns.tsplot(data=X)

# %%
X = MinMaxScaler().fit_transform([float(d[3]) for d in data])
# Out:
# /Users/stuartfarmer/miniconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/stuartfarmer/miniconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
d = [float(d[3]) for d in data]

# %%
ax = sns.tsplot(data=d)

# %%
diff = []
prior = None
for dd in d:
    if prior != None:
        diff.append(dd-prior)
    prior = dd

# %%
ax = sns.tsplot(data=diff)

# %%
D = MinMaxScaler().fit_transform(diff)
# Out:
# /Users/stuartfarmer/miniconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/stuartfarmer/miniconda3/lib/python3.5/site-packages/sklearn/preprocessing/data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
ax = sns.tsplot(data=D)

# %%
pprint.pprint(D.tolist())
# Out:
# [0.4019292604501606,
#  0.5734190782422298,
#  0.4844587352625943,
#  0.367631296891747,
#  0.46302250803858563,
#  0.5058949624866017,
#  0.6173633440514474,
#  0.3954983922829587,
#  0.44801714898177886,
#  0.4619506966773853,
#  0.4748124330117891,
#  0.576634512325832,
#  0.3376205787781346,
#  0.5884244372990355,
#  0.3847802786709544,
#  0.3547695605573408,
#  0.5755627009646305,
#  0.4523043944265813,
#  0.3912111468381563,
#  0.6463022508038595,
#  0.6205787781350485,
#  0.45659163987138257,
#  0.47909967845659274,
#  0.4598070739549835,
#  0.38156484458735224,
#  0.4855305466237946,
#  0.38263665594855256,
#  0.6195069667738481,
#  0.46409431939978596,
#  0.40836012861736365,
#  0.44480171489817794,
#  0.409431939978564,
#  0.5519828510182212,
#  0.5016077170418005,
#  0.451232583065381,
#  0.4608788853161838,
#  0.44158628081457696,
#  0.5723472668810295,
#  0.5112540192926045,
#  0.5423365487674172,
#  0.5359056806002142,
#  0.5948553054662385,
#  0.43837084673097604,
# ...

# %%
pprint.pprint(X.tolist())
# Out:
# [0.1524888069528576,
#  0.1419541743481696,
#  0.1524888069528576,
#  0.15209375823018179,
#  0.13734527258361884,
#  0.13431656570977113,
#  0.1365551751382672,
#  0.1524888069528576,
#  0.14116407690281818,
#  0.13629180932315,
#  0.13313141954174368,
#  0.1315512246510404,
#  0.14248090597840424,
#  0.12404529892020033,
#  0.1364234922307086,
#  0.12378193310508312,
#  0.10745325256781668,
#  0.1182512509876219,
#  0.11390571503818814,
#  0.10205425335791429,
#  0.12154332367658682,
#  0.13787200421385304,
#  0.1340531998946537,
#  0.13299973663418507,
#  0.12957598103766133,
#  0.11653937318936003,
#  0.11627600737424282,
#  0.10337108243350013,
#  0.11956808006320774,
#  0.11667105609691863,
#  0.10692652093758248,
#  0.10165920463523848,
#  0.0920463523834607,
#  0.0999473268369766,
#  0.10165920463523848,
#  0.0971819857782461,
#  0.09388991308928119,
#  0.08822754806426136,
#  0.09863049776139077,
#  0.10152752172767987,
#  0.10824335001316832,
#  0.11416908085330535,
# ...
